# %% [markdown]
# ### Finding 1: Consistent NAV growth across mutual fund schemes
#
# The indexed NAV trend shows that all 40 mutual fund schemes experienced overall growth between January 2022 and May 2026, although the pace of growth varied across schemes.
#
# *See Chart: NAV Trend Analysis (Task 1).*

# %% [markdown]
# ### Finding 2: SBI Mutual Fund maintained the largest AUM
#
# Among the selected fund houses, SBI Mutual Fund recorded the highest Assets Under Management (AUM), reaching approximately ₹12.5 lakh crore by 2025.
#
# *See Chart: AUM Growth by Fund House (Task 2).*

# %% [markdown]
# ### Finding 3: Monthly SIP inflows reached a record high
#
# Monthly SIP inflows increased steadily throughout the analysis period, reaching an all-time high of ₹31,002 crore in December 2025.
#
# *See Chart: Monthly SIP Inflow Trend (Task 3).*

# %% [markdown]
# ### Finding 4: Category inflows varied significantly across fund categories
#
# The category inflow heatmap shows clear differences in monthly investment patterns, with some categories consistently attracting higher inflows than others.
#
# *See Chart: Category Inflow Heatmap (Task 4).*

# %% [markdown]
# ### Finding 5: Investors aged 26–35 formed the largest investor group
#
# The investor demographics analysis indicates that the 26–35 age group represents the largest share of investors, while the gender distribution shows higher participation from male investors.
#
# *See Chart: Investor Demographics (Task 5).*

# %% [markdown]
# ### Finding 6: Investment activity is concentrated in T30 cities
#
# Most investment value originates from T30 cities, while B30 cities contribute a smaller share, indicating stronger participation from major urban centers.
#
# *See Chart: Geographic Distribution (Task 6).*

# %% [markdown]
# ### Finding 7: Industry folio count nearly doubled
#
# Total investor folios increased from 13.26 crore in January 2022 to 26.12 crore in December 2025, reflecting strong growth in retail participation.
#
# *See Chart: Folio Count Growth (Task 7).*

# %% [markdown]
# ### Finding 8: Daily return correlations are generally low
#
# The daily return correlation matrix shows relatively weak correlations among the selected funds, suggesting limited day-to-day co-movement within this dataset.
#
# *See Chart: NAV Return Correlation Matrix (Task 8).*

# %% [markdown]
# ### Finding 9: Banking has the highest portfolio allocation
#
# After aggregating holdings across all equity funds, the Banking sector accounts for the largest share of portfolio allocation, followed by IT and Pharma.
#
# *See Chart: Sector Allocation Donut Chart (Task 9).*

# %% [markdown]
# ### Finding 10: Multiple EDA visualizations provide a comprehensive view of the mutual fund industry
#
# The combined EDA highlights strong growth in NAVs, AUM, SIP inflows, investor participation, and folio counts while also illustrating portfolio composition and fund relationships through correlation and sector allocation analyses.
#
# *See Charts: Tasks 1–9.*
